# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
import pandas as pd

#  muestra el nombres de las columnas
a=ds.columns.values

#muestra el indice del precio maximo

indice_max=ds["price"].idxmax()

#muestra la direccion del precio maximo
direccion=ds.loc[indice_max,"address"]

#muestra el precio del precio maximo
precio=ds.loc[indice_max,"price"]

print(f"La casa {indice_max} con direccion {direccion}, es la mas cara y su precio es de:{precio}")
# Out:
# La casa 13110 con direccion El Escorial, es la mas cara y su precio es de:8500000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO

#muestra el indice del precio maximo
indice_min=ds["price"].idxmin()

#muestra la direccion del precio maximo
direccion_min=ds.loc[indice_min,"address"]

#muestra el precio del precio maximo
precio_min=ds.loc[indice_min,"price"]

print(f"La casa {indice_min} con direccion {direccion_min}, es la mas barata y su precio es de:{precio_min}")
# Out:
# La casa 366 con direccion Parla, es la mas barata y su precio es de:0

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
#  muestra el nombres de las columnas
a=ds.columns.values
print(a)


#muestra el indice del precio maximo

indice_max_surface=ds["surface"].idxmax()

#muestra la direccion del precio maximo
direccion_surface_max=ds.loc[indice_max_surface,"address"]

#muestra el precio del precio maximo
surface_max=ds.loc[indice_max_surface,"surface"]

print(f"La casa {indice_max_surface} mas grande esta ubicada en {direccion_surface_max}, y su superficie es de {surface_max}")
# Out:
# ['Unnamed: 0' 'id_realEstates' 'isNew' 'realEstate_name'
#  'phone_realEstate' 'url_inmueble' 'rooms' 'bathrooms' 'surface' 'price'
#  'date' 'description' 'address' 'country' 'level1' 'level2' 'level3'
#  'level4' 'level5' 'level6' 'level7' 'level8' 'upperLevel' 'countryId'
#  'level1Id' 'level2Id' 'level3Id' 'level4Id' 'level5Id' 'level6Id'
#  'level7Id' 'level8Id' 'accuracy' 'latitude' 'longitude' 'zipCode'
#  'customZone']
# La casa 6794 mas grande esta ubicada en Sevilla la Nueva, y su superficie es de 249000.0

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

poblaciones=ds["level5"].unique().tolist()
print(f"El nombre de las poblaciones es:{poblaciones}")
# Out:
# El nombre de las poblaciones es:['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte', 'Las Rozas de Madrid', ' Madrid Capital', 'Villaviciosa de Odón', 'Pinto', 'Valdemoro', 'Navalcarnero', 'Pozuelo de Alarcón', 'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes', 'Rivas-vaciamadrid', 'Alpedrete', 'Móstoles', 'San Fernando de Henares', 'Coslada', 'Becerril de la Sierra', 'Alcalá de Henares', 'Chinchón', 'Parla', 'Alcorcón', 'El Escorial', 'Leganés', 'Pedrezuela', 'Majadahonda', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'Torrelodones', 'Moralzarzal', 'Mejorada del Campo', 'Aranjuez', 'Corpa', 'Getafe', 'Velilla de San Antonio', 'Sevilla la Nueva', 'San Martín de la Vega', 'Villalbilla', 'Collado Villalba', 'Alcobendas', 'El Molar (Madrid)', 'Moraleja de Enmedio', 'Algete', 'Campo Real', 'Torrejón de la Calzada', 'Colmenar Viejo', 'Valdemorillo', 'Fuente El Saz de Jarama', 'Tres Cantos', 'Arroyomolinos (Madrid)', 'Griñón', 'Paracuellos de Jarama', 'Guadarr
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

for index, row in ds.iterrows():
    if row.isnull().any():
        print(f"True - Fila: {index}")
        for col, value in enumerate(row):
            if pd.isna(value):
                print(f"  Columna: {ds.columns[col]}")
    else:
        print(f"False - Fila: {index}")
# Out:
# False - Fila: 0
# False - Fila: 1
# False - Fila: 2
# False - Fila: 3
# False - Fila: 4
# False - Fila: 5
# False - Fila: 6
# False - Fila: 7
# False - Fila: 8
# False - Fila: 9
# False - Fila: 10
# False - Fila: 11
# False - Fila: 12
# False - Fila: 13
# False - Fila: 14
# False - Fila: 15
# False - Fila: 16
# False - Fila: 17
# False - Fila: 18
# False - Fila: 19
# False - Fila: 20
# False - Fila: 21
# False - Fila: 22
# False - Fila: 23
# False - Fila: 24
# False - Fila: 25
# False - Fila: 26
# False - Fila: 27
# False - Fila: 28
# False - Fila: 29
# False - Fila: 30
# False - Fila: 31
# False - Fila: 32
# False - Fila: 33
# False - Fila: 34
# False - Fila: 35
# False - Fila: 36
# False - Fila: 37
# False - Fila: 38
# False - Fila: 39
# False - Fila: 40
# False - Fila: 41
# False - Fila: 42
# False - Fila: 43
# False - Fila: 44
# False - Fila: 45
# False - Fila: 46
# False - Fila: 47
# False - Fila: 48
# False - Fila: 49
# False - Fila: 50
# False - Fila: 51
# False - Fila: 52
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO

ds.fillna(0, inplace=True)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO


ds_arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']
media_arroyomolinos = ds_arroyomolinos['price'].mean()

print(f"La media de los precios en Arroyomolinos (Madrid) es: {media_arroyomolinos}")
# Out:
# La media de los precios en Arroyomolinos (Madrid) es: 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code

ds_arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']
precio_arroyomolinos = ds_arroyomolinos['price']


plt.figure(figsize=(10, 5))
plt.hist(precio_arroyomolinos, bins=15, color='blue', alpha=0.7, label='Distribución de precios')
plt.title("Distribución de Precios en Arroyomolinos (Madrid)", fontsize=14)
plt.xlabel("Precio", fontsize=12)
plt.ylabel("Frecuencia", fontsize=12)
plt.legend(loc="upper right")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Los datos de los precios se concentran entre 2000 y 3800, hay pocos datos que se situan en los extremos

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
ds_valdemorillo = ds[ds['level5'] == 'Valdemorillo']
media_valdemorillo = ds_valdemorillo.groupby('level5')['price'].mean()

ds_galapagar = ds[ds['level5'] == 'Galapagar']
media_galapagar = ds_galapagar.groupby('level5')['price'].mean()



print(f"La media de los precios en Valdemorillo es: {media_valdemorillo.iloc[0]}")

print(f"La media de los precios en Galapagar es: {media_galapagar.iloc[0]}")
# Out:
# La media de los precios en Valdemorillo es: 363860.2931034483
# La media de los precios en Galapagar es: 360063.20238095237

# %% [markdown]
# Los precios de estas dos zonas tienen una pequeña diferencia entre ellas, segun los precios y el numero de casas tienen un promedio muy parecid

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

ds['precio_m2'] = ds['price']/ds['surface']
ds.head()

ds_valdemorillo = ds[ds['level5'] == 'Valdemorillo']
media_valdemorillo = ds_valdemorillo.groupby('level5')['precio_m2'].mean()

ds_galapagar = ds[ds['level5'] == 'Galapagar']
media_galapagar = ds_galapagar.groupby('level5')['precio_m2'].mean()



print(f"La media de los precios en Valdemorillo es: {media_valdemorillo.iloc[0]}")

print(f"La media de los precios en Galapagar es: {media_galapagar.iloc[0]}")
# Out:
# La media de los precios en Valdemorillo es: inf
# La media de los precios en Galapagar es: inf

# %% [markdown]
# La media de los precios no son los mismos, la diferencia es pequeña pero significativa, la cual nos ayudará a tomar una mejor decision de compra

# %% [markdown]
# Galapagar tiene los precios mas altos por metro cuadrado

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código

plt.figure(figsize=(10,5))
plt.scatter(ds['surface'], ds['price'], color='blue', alpha=0.5, label='Relación Superficie-Precio')
plt.title("Relacion de superficie")
plt.xlabel("Superficie")
plt.ylabel("Precio")
plt.legend(loc="upper left")
plt.grid(True)

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO


Total_agencia=ds["realEstate_name"].unique()

print(f"Total de agencias:{len(Total_agencia)}")
# Out:
# Total de agencias:1822

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
conteo_poblaciones = ds["level5"].value_counts()

# Obtener la población con mayor cantidad de casas
poblacion_mas_casas = conteo_poblaciones.idxmax()
numero_casas = conteo_poblaciones.max()

# Imprimir los resultados
print(f"La población con más casas es: {poblacion_mas_casas}")
print(f"Número de casas: {numero_casas}")
# Out:
# La población con más casas es:  Madrid Capital
# Número de casas: 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO

Cinturon_sur = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

# Imprimir el resultado
print(Cinturon_sur)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               0.0
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code


ds_cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
mediana_cinturon_sur = ds_cinturon_sur.groupby('level5')['price'].median()
print(mediana_cinturon_sur)

plt.figure(figsize=(10, 5))
plt.bar(mediana_cinturon_sur.index, mediana_cinturon_sur.values, color='blue', alpha=0.7, label='Mediana de Precio')
plt.title("Mediana de Precios (Cinturon-Sur)", fontsize=14)
plt.xlabel("Población", fontsize=12)
plt.ylabel("Precio (mediana)", fontsize=12)
plt.legend(loc="upper right")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# level5
# Alcorcón       179500.0
# Fuenlabrada    155000.0
# Getafe         285305.0
# Leganés        169950.0
# Name: price, dtype: float64

# %% [markdown]
# Los precios de alcorcon, Fuenlabrada y Leganes son muy parecidas, mientras que Gatafe muestra un precio mas elevado para sus casas.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
Cinturon_sur = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

Mean_cinturon_precio = Cinturon_sur.groupby('level5')['price'].mean()
Var_cinturon_precio = Cinturon_sur.groupby('level5')['price'].var()

Mean_cinturon_habitacion = Cinturon_sur.groupby('level5')['rooms'].mean()
Var_cinturon_habitacion = Cinturon_sur.groupby('level5')['rooms'].var()

Mean_cinturon_superficie = Cinturon_sur.groupby('level5')['surface'].mean()
Var_cinturon_superficie = Cinturon_sur.groupby('level5')['surface'].var()

Mean_cinturon_baños = Cinturon_sur.groupby('level5')['bathrooms'].mean()
Var_cinturon_baños = Cinturon_sur.groupby('level5')['bathrooms'].var()

print(f"MEDIA DE PRECIO \n {Mean_cinturon_precio.iloc[0]}\nVARIANZA DE PRECIOS\n{Var_cinturon_precio.iloc[0]}")
print()
print(f"MEDIA DE HABITACIONES \n {Mean_cinturon_habitacion.iloc[0]}\nVARIANZA DE HABITACONES\n{Var_cinturon_habitacion.iloc[0]}")
print()
print(f"MEDIA DE SUPERFICIE \n {Mean_cinturon_superficie.iloc[0]}\nVARIANZA DE SUPERFICIE\n{Var_cinturon_superficie.iloc[0]}")
print()
print(f"MEDIA DE NUMERO DE BAÑOS \n {Mean_cinturon_baños.iloc[0]}\nVARIANZA DE NUMERO DE BAÑOS\n{Var_cinturon_baños.iloc[0]}")
# Out:
# MEDIA DE PRECIO
#  230071.05263157896
# VARIANZA DE PRECIOS
# 15947825983.013088
#
# MEDIA DE HABITACIONES
#  2.8842105263157896
# VARIANZA DE HABITACONES
# 1.0129768866610973
#
# MEDIA DE SUPERFICIE
#  96.43684210526315
# VARIANZA DE SUPERFICIE
# 4781.273767752714
#
# MEDIA DE NUMERO DE BAÑOS
#  1.5894736842105264
# VARIANZA DE NUMERO DE BAÑOS
# 0.6348092453355613

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
mediana_cinturon_sur = ds_cinturon_sur.groupby('level5')['price'].median()

Cinturon_sur = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
casa_mas_cara_sur=Cinturon_sur.groupby("level5")["price"].max()
print(casa_mas_cara_sur)
# Out:
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000
# Name: price, dtype: int64

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
Cinturon_sur['precio_normalizado'] = Cinturon_sur.groupby('level5')["price"].transform(
    lambda x: (x - x.mean()) / x.std()
)

plt.figure(figsize=(10, 6))

for poblacion in Cinturon_sur['level5'].unique():
    subset = Cinturon_sur[Cinturon_sur['level5'] == poblacion]
    plt.hist(
        subset['precio_normalizado'], 
        bins=20, 
        alpha=0.5, 
        label=poblacion, 
        density=True
    )
plt.title("Histograma de precios normalizados por población")
plt.xlabel("Precio Normalizado")
plt.ylabel("Densidad")
plt.legend(title="Población")
plt.grid(alpha=0.3)

plt.show()
# Out:
# /tmp/ipykernel_1211/3943218674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cinturon_sur['precio_normalizado'] = Cinturon_sur.groupby('level5')["price"].transform(

# %% [markdown]
# Se puede apreciar que los precios de todas las poblaciones tienen una distribucion muy parecida

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
Cinturon_sur = ds[ds["level5"].isin(["Getafe", "Alcorcón"])]

plt.figure(figsize=(10, 6))

for poblacion in Cinturon_sur["level5"].unique():
    subset = Cinturon_sur[Cinturon_sur["level5"] == poblacion]
    plt.scatter(
        subset["surface"], 
        subset["price"], 
        label=poblacion, 
        alpha=0.7
    )

plt.title("Relación entre superficie y precio por población")
plt.xlabel("Superficie (m²)")
plt.ylabel("Precio (€)")
plt.legend(title="Población")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Los precios por metro cuadrado de estas dos poblaciones nos indican un promedio muy similar ya que los histogramas se superponen, justo en la mayor distribucion los dos estan separdos, lo que indica que uno es mayor que otro en este caso Alcorcon tiene una densidad mayor en entre los precios de 1800 y 2500

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO


Cinturon_sur = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

plt.figure(figsize=(10, 6))

for poblacion in Cinturon_sur["level5"].unique():
    subset = Cinturon_sur[Cinturon_sur["level5"] == poblacion]
    plt.scatter(
        subset["surface"], 
        subset["price"], 
        label=poblacion, 
        alpha=0.7
    )

plt.title("Relación entre superficie y precio por población")
plt.xlabel("Superficie (m²)")
plt.ylabel("Precio (€)")
plt.legend(title="Población")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps, CircleMarker, LayerGroup


Cinturon_sur = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

mapa = Map(center=(40.32, -3.79), zoom=11, basemap=basemaps.OpenStreetMap.Mapnik)

# Diccionario de colores para los marcadores
colores = {"Getafe": "red", "Fuenlabrada": "blue", "Leganés": "green", "Alcorcón": "yellow"}

# Crear marcadores para cada fila del DataFrame
marcadores = []
for i, row in Cinturon_sur.iterrows():
    marcador = Marker(
        location=(row["latitude"], row["longitude"]),  # Latitud y longitud
        draggable=False,
        title=row["level5"]
    )
    marcador.color = colores[row["level5"]]  # Color del marcador
    marcadores.append(marcador)

cluster = MarkerCluster(markers=marcadores)
mapa.add_layer(cluster)

# Mostrar el mapa
mapa
# Out:
# Map(center=[40.32, -3.79], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_o…

# %%
from ipyleaflet import Map, basemaps, CircleMarker, LayerGroup

# Filtrar el subconjunto para "Fuenlabrada"
fuenlabrada_subset = Cinturon_sur[Cinturon_sur["level5"] == "Fuenlabrada"]

# Crear el mapa centrado en Fuenlabrada
mapa = Map(center=(40.2833, -3.7933), zoom=13, basemap=basemaps.OpenStreetMap.Mapnik)

# Crear un grupo de capas para Fuenlabrada
layer_group = LayerGroup(name="Fuenlabrada")

# Agregar marcadores verdes para cada índice de "Fuenlabrada"
for i, row in fuenlabrada_subset.iterrows():
    circle_marker = CircleMarker(
        location=(row["latitude"], row["longitude"]),  # Latitud y longitud
        radius=5,  # Tamaño del marcador
        color="green",  # Color del borde
        fill_color="green",  # Color del interior
        fill_opacity=0.7,  # Transparencia del relleno
        title=f"Index: {i}, Fuenlabrada"  # Título al pasar el cursor
    )
    layer_group.add_layer(circle_marker)

# Agregar el grupo al mapa
mapa.add_layer(layer_group)

# Mostrar el mapa
mapa
# Out:
# Map(center=[40.2833, -3.7933], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…
